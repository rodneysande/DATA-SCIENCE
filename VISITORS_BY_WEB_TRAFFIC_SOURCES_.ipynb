# %% [markdown]
# <a href="https://colab.research.google.com/github/rodneysande/DATA-SCIENCE/blob/main/VISITORS_BY_WEB_TRAFFIC_SOURCES_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task
# Create a grouped bar chart for the data in the "VISITORS BY WEB TRAFFIC SOURCES.xlsx" file.

# %% [markdown]
# ## Load the data
#
# ### Subtask:
# Load the data from the "VISITORS BY WEB TRAFFIC SOURCES.xlsx" file into a pandas DataFrame.

# %% [markdown]
# **Reasoning**:
# Import pandas and load the Excel file into a DataFrame as instructed.

# %%
import pandas as pd

df_visitors = pd.read_excel("VISITORS BY WEB TRAFFIC SOURCES.xlsx")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Convert 'Month' to datetime and format it for better display on the x-axis
df_melted['Month'] = pd.to_datetime(df_melted['Month']).dt.strftime('%Y-%m')

plt.figure(figsize=(10, 6))
sns.barplot(x='Month', y='Visitors', hue='Web Traffic Source', data=df_melted)
plt.title("Monthly Visitors by Web Traffic Source")
plt.xlabel("Month")
plt.ylabel("Visitors (in thousands)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
